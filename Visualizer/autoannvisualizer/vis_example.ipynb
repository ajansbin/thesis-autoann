# %% [markdown]
# ### Mini - Train

# %%
import importlib
import visualizer
importlib.reload(visualizer)
import visualizer

conf_name = 'vehicle-w9-lr1-4-ef-l1-giou03-ts09_conf.json'
conf_path = f'/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/results/pc-track/{conf_name}'
version = 'mini'
split = "val"
result_path = f"/staging/agp/masterthesis/2023autoann/storage/tracking/SimpleTrack_zod_{version}_{split}_1/results/Vehicle/results.json"
data_path = "/datasets/zod/zodv2"
model_name= 'vehicle-w9-lr1-4-ef-l1-giou03-ts09_model.pth'
model_path = f'/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/results/pc-track/{model_name}'
remove_non_foi_tracks = True
remove_non_gt_tracks = False

viz_mini = visualizer.VisualizeResults(conf_path, version, split, result_path, data_path, remove_non_foi_tracks, remove_non_gt_tracks)
viz_mini.load_model(model_path)
# Out:
# Initializing ZodData class...
# Loading prediction and ground-truths ...
# ...
# 100%|██████████| 1/1 [00:00<00:00,  9.58it/s]
# Loading sequences...
# 100%|██████████| 1/1 [00:00<00:00,  4.01it/s]
# Finished loading 17 data samples!
# Succefully loaded model vehicle-w9-lr1-4-ef-l1-giou03-ts09_model.pth

# %%
### Load new model ###
model_path = '/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/results/pc-track/vehicle-w9-lr1-4-ef-l1-giou03-ts09-rnd_model.pth'
viz_mini.load_model(model_path)
# Out:
# Succefully loaded model vehicle-w9-lr1-4-ef-l1-giou03-ts09-rnd_model.pth

# %%
track_index = 9
frame_track_index = 45
viz_mini.plot_track_index(track_index, frame_track_index, show_lidar=False, show_det=True, show_ref=True, show_gt=True, score_thresh=0)
# Out:
# Showing track {'sequence_id': '000002', 'tracking_id': 'Vehicle_0_60', 'starting_frame_index': 44, 'track_length': 55, 'foi_index': 89, 'assoc_metric': 'giou', 'assoc_thresh': 0.3, 'has_gt': True, 'gt_dist': tensor(0.7543, dtype=torch.float64)}
# loading point_clouds_000002_Vehicle_0_60.npy
# init shape torch.Size([55, 1000, 3])
# return shape torch.Size([55, 1000, 3])

# %%
seq_id = '000002'
out_dir = '/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/viz'
gif_name = f'sequence_tracks_{seq_id}_new.gif'
step = 2
duration = 400
show_lidar = False
show_det = True
show_ref = True
show_gt = False

viz_mini.generate_sequence_gif(seq_id, out_dir, gif_name, step, duration, show_lidar, show_det, show_ref, show_gt)
# Out:
# Found 17 number of tracks in sequence
# loading point_clouds_000002_Vehicle_0_5.npy
# init shape torch.Size([127, 1000, 3])
# return shape torch.Size([127, 1000, 3])
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[43], line 11
#       8 show_ref = True
#       9 show_gt = False
# ---> 11 viz_mini.generate_sequence_gif(seq_id, out_dir, gif_name, step, duration, show_lidar, show_det, show_ref, show_gt)
#
# File ~/workspace/thesis-autoann/Visualizer/autoannvisualizer/visualizer.py:237, in VisualizeResults.generate_sequence_gif(self, seq_id, output_dir, gif_name, step, duration, show_lidar, show_det, show_ref, show_gt, score_thresh)
#     234 _, points, _ = self.track_data[track_index]
#     235 points = points[:, :, :3]
#     236 masked_lidar = self._get_masked_lidar(
# --> 237     track_box3d,
#     238     track_box.frame_token,
#     239     track_box.frame_index,
# ...

# %%
viz_mini.plot_bev(
            '001042', 
            88,
            '/home/s0001668/workspace/storage/tracking/visualized/full_train_gt/000000.png',
            show_det=True,
            show_ref=True,
            show_gt=True,
            score_thresh=0.0,
    )
# Out:
# Starting BEV visualizing
# 100%|██████████| 1/1 [00:09<00:00,  9.41s/it]

# %%
viz_mini.create_bev_animation(
            '001042', 
            '/home/s0001668/workspace/storage/tracking/visualized/full_train_gt/001042.gif',
            show_det=True,
            show_ref=True,
            show_gt=True,
            score_thresh=0.0,
    )
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 viz_mini.create_bev_animation(
#       2             '000000',
#       3             '/home/s0001668/workspace/storage/tracking/visualized/full_train_gt/000000.gif',
#       4             show_det=True,
#       5             show_ref=True,
#       6             show_gt=True,
#       7             score_thresh=0.0,
#       8     )
#
# File ~/workspace/thesis-autoann/Visualizer/autoannvisualizer/visualizer.py:596, in VisualizeResults.create_bev_animation(self, seq_id, save_path, show_det, show_ref, show_gt, score_thresh)
#     593     visualize_boxes.append((track_box3d, 'Vehicle', 'det'))
#     595 if show_ref:
# --> 596     ref_box, score = self._get_refined_box(
#     597         self.trained_model,
#     598         self.track_data,
#     599         track_index,
# ...

# %% [markdown]
# ### Full - Train

# %%
import importlib
import visualizer
importlib.reload(visualizer)
import visualizer

conf_name = 'w9-rndslides-lr3-3-wd1-3-scheduler_conf.json'
conf_path = f'/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/pc-track/{conf_name}'
version = 'full'
split = "train"
result_path = f"/staging/agp/masterthesis/2023autoann/storage/tracking/SimpleTrack_zod_{version}_{split}/results/Vehicle/results.json"
data_path = "/datasets/zod/zodv2"
model_name= 'w9-rndslides-lr3-3-wd1-3-scheduler_model.pth'
model_path = f'/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/pc-track/{model_name}'
remove_non_foi_tracks = False
remove_non_gt_tracks = False

viz_full = visualizer.VisualizeResults(conf_path, version, split, result_path, data_path, remove_non_foi_tracks, remove_non_gt_tracks)
viz_full.load_model(model_path)
# Out:
# Initializing ZodData class...
# Loading infos: 0it [00:00, ?it/s]
# Loading prediction and ground-truths ...
# ...
# 100%|██████████| 1165/1165 [02:18<00:00,  8.39it/s]
# Loading sequences...
# 100%|██████████| 1165/1165 [02:58<00:00,  6.54it/s]
# Finished loading 71598 data samples!
# Succefully loaded model w9-rndslides-lr3-3-wd1-3-scheduler_model.pth

# %%
### Load new model ###
model_path = '/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/pc-track/w25-no-sw-oldanno_model.pth'
viz_full.load_model(model_path)
# Out:
# Succefully loaded model w25-no-sw-oldanno_model.pth

# %%
track_index = 560
frame_track_index = 0
viz_full.plot_track_index(track_index, frame_track_index, show_lidar=True, show_det=True, show_ref=True, show_gt=True, score_thresh=0.5)

#interesting: 1199, 7001 (28)
# Out:
# Showing track {'sequence_id': '001328', 'tracking_id': 'Vehicle_1057_26', 'starting_frame_index': 22, 'track_length': 36, 'foi_index': None, 'assoc_metric': 'giou', 'assoc_thresh': 0.0, 'has_gt': False, 'gt_dist': None}
# (254709, 3)
# 0 -129.23497 218.80447
# 1 -245.70967 236.52258
# 2 -4.7379084 38.7576
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 3
#       1 track_index = 560
#       2 frame_track_index = 0
# ----> 3 viz_full.plot_track_index(track_index, frame_track_index, show_lidar=True, show_det=True, show_ref=True, show_gt=True, score_thresh=0.5)
#       5 #interesting: 1199, 7001 (28)
#
# File ~/workspace/thesis-autoann/Visualizer/autoannvisualizer/visualizer.py:145, in VisualizeResults.plot_track_index(self, track_index, frame_track_index, show_lidar, show_det, show_ref, show_gt, score_thresh)
# ...

# %%
viz_full.track_data.slides
# Out:
# 1

# %%
seq_id = '000217'
out_dir = '/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/viz'
gif_name = f'sequence_tracks_{seq_id}_new.gif'
step = 2
duration = 400
show_lidar = False
show_det = True
show_ref = True
show_gt = False

viz_full.generate_sequence_gif(seq_id, out_dir, gif_name, step, duration, show_lidar, show_det, show_ref, show_gt)
# Out:
# Found 4 number of tracks in sequence
# torch.Size([1, 25, 8]) torch.Size([1, 25, 1000, 4])
# torch.Size([1, 25, 3]) torch.Size([1, 3]) torch.Size([1, 25, 1]) torch.Size([1, 25, 1])
# torch.Size([1, 25, 8]) torch.Size([1, 25, 1000, 4])
# torch.Size([1, 25, 3]) torch.Size([1, 3]) torch.Size([1, 25, 1]) torch.Size([1, 25, 1])
# torch.Size([1, 25, 8]) torch.Size([1, 25, 1000, 4])
# torch.Size([1, 25, 3]) torch.Size([1, 3]) torch.Size([1, 25, 1]) torch.Size([1, 25, 1])
# torch.Size([1, 25, 8]) torch.Size([1, 25, 1000, 4])
# torch.Size([1, 25, 3]) torch.Size([1, 3]) torch.Size([1, 25, 1]) torch.Size([1, 25, 1])
# torch.Size([1, 25, 8]) torch.Size([1, 25, 1000, 4])
# torch.Size([1, 25, 3]) torch.Size([1, 3]) torch.Size([1, 25, 1]) torch.Size([1, 25, 1])
# torch.Size([1, 25, 8]) torch.Size([1, 25, 1000, 4])
# torch.Size([1, 25, 3]) torch.Size([1, 3]) torch.Size([1, 25, 1]) torch.Size([1, 25, 1])
# torch.Size([1, 25, 8]) torch.Size([1, 25, 1000, 4])
# ...
