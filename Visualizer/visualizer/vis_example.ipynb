# %%
import importlib
import visualizer
importlib.reload(visualizer)
import visualizer

conf_path = '/home/s0001671/workspace/thesis-autoann/AutoAnnSmoother/configs/training_config.yaml'
version = 'mini'
split = "train"
result_path = f"/staging/agp/masterthesis/2023autoann/storage/tracking/SimpleTrack_zod_{version}_{split}/results/Vehicle/results_lidar.json"
data_path = "/datasets/zod/zodv2"
model_path = '/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/pc-track/zod_test_model.pth'
remove_non_foi_tracks = False
remove_non_gt_tracks = False

viz = visualizer.VisualizeResults(conf_path, version, split, result_path, data_path, model_path, remove_non_foi_tracks, remove_non_gt_tracks)
# Out:
# Initializing ZodData class...
# Loading prediction and ground-truths ...
# ...
# 100%|██████████| 1/1 [00:00<00:00, 94.18it/s]
# Loading data samples
# 100%|██████████| 1/1 [00:00<00:00, 16.89it/s]
# Finished loading 2 data samples!
# ---Loading model---
# ---Finished loading trained model---

# %%
track_index = 0
frame_track_index = 20
viz.plot_track_index(track_index, frame_track_index, show_lidar=False, show_det=True, show_ref=True, show_gt=False)
# Out:
# Showing track {'sequence_id': '000000', 'tracking_id': 'Vehicle_0_10', 'starting_frame_index': 70, 'track_length': 32, 'foi_index': 88, 'assoc_metric': 'giou', 'assoc_thresh': 0.0, 'has_gt': True, 'gt_dist': tensor(0.5794, dtype=torch.float64)}

# %%
print(viz.track_data.get(0).gt_box)

viz.track_data.get(0).get_foi_box()
# Out:
# {'sample_token': '000000', 'translation': [5.124, 22.317, -1.44], 'size': [4.594, 1.88, 1.819], 'rotation': [-0.10216830100909255, 0.9947671276579838], 'velocity': [0.0, 0.0], 'detection_name': 'Vehicle', 'detection_score': -1.0, 'attribute_name': 'Car', 'instance_token': '626218F3-CD3B-40AE-9D09-50004257FB83', 'name': 'Vehicle'}
# TrackingBox(tracking_id='Vehicle_0_10', center=[4.994181518529014, 22.647279932471744, -1.550068295257373], size=[4.361130391550282, 1.9016886441699505, 1.6881772852683796], rotation=[-0.12903031067116205, 0.9916406500986652], is_foi=True, frame_index=88, frame_token='000000_quebec_2022-02-14T13:23:42.026644Z.npy', tracking_name='Vehicle', center_offset=None, yaw_offset=None)

# %%
seq_id = '000308'
out_dir = '/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/viz'
gif_name = f'sequence_tracks_{seq_id}_sw_lstm.gif'
step = 2
duration = 400
show_lidar = False
show_det = True
show_ref = True
show_gt = False

viz.generate_sequence_gif(seq_id, out_dir, gif_name, step, duration, show_lidar, show_det, show_ref, show_gt)
# Out:
# Found 38 number of tracks in sequence
# Generated sequence gif at /staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/viz/sequence_tracks_000308_sw_lstm.gif
