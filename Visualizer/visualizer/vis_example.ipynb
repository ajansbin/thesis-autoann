# %%
import importlib
import visualizer
importlib.reload(visualizer)
import visualizer

conf_path = '/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/pc-track/config-w9.yaml'
version = 'mini'
split = "train"
result_path = f"/staging/agp/masterthesis/2023autoann/storage/tracking/SimpleTrack_zod_{version}_{split}/results/Vehicle/results_lidar.json"
data_path = "/datasets/zod/zodv2"
model_path = '/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/pc-track/w9-sw-transformer-res-e100_model.pth'
remove_non_foi_tracks = False
remove_non_gt_tracks = False
sw_refine = True

viz = visualizer.VisualizeResults(conf_path, version, split, result_path, data_path, model_path, remove_non_foi_tracks, remove_non_gt_tracks, sw_refine)
# Out:
# Initializing ZodData class...
# Loading prediction and ground-truths ...
# ...
# 100%|██████████| 1/1 [00:00<00:00, 44.55it/s]
# Loading sequences...
# 100%|██████████| 1/1 [00:00<00:00, 19.68it/s]
# Finished loading 315 data samples!
# ---Loading model---
# /home/s0001671/miniconda3/envs/spot_env/lib/python3.8/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at  /opt/conda/conda-bld/pytorch_1623448278899/work/c10/cuda/CUDAFunctions.cpp:115.)
#   return torch._C._cuda_getDeviceCount() > 0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 16
#      13 remove_non_gt_tracks = False
#      14 sw_refine = True
# ...

# %%
track_index = 90
frame_track_index = 20
viz.plot_track_index(track_index, frame_track_index, show_lidar=True, show_det=True, show_ref=True, show_gt=False)
# Out:
# Showing track {'sequence_id': '000566', 'tracking_id': 'Vehicle_447_35', 'starting_frame_index': 47, 'track_length': 63, 'foi_index': 89, 'assoc_metric': 'giou', 'assoc_thresh': 0.0, 'has_gt': True, 'gt_dist': tensor(0.3952, dtype=torch.float64)}

# %%
seq_id = '000566'
out_dir = '/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/viz'
gif_name = f'sequence_tracks_{seq_id}.gif'
step = 2
duration = 400
show_lidar = False
show_det = True
show_ref = True
show_gt = False

viz.generate_sequence_gif(seq_id, out_dir, gif_name, step, duration, show_lidar, show_det, show_ref, show_gt)
# Out:
# Found 22 number of tracks in sequence
# Generated sequence gif at /staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/viz/sequence_tracks_000566.gif
