# %% [markdown]
# ### Mini - Train

# %%
import importlib
import visualizer
importlib.reload(visualizer)
import visualizer

conf_path = '/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/pc-track/config.yaml'
version = 'mini'
split = "train"
result_path = f"/staging/agp/masterthesis/2023autoann/storage/tracking/SimpleTrack_zod_{version}_{split}/results/Vehicle/results_lidar.json"
anno_path = '/staging/agp/masterthesis/2023autoann/storage/annotations.json'
data_path = "/datasets/zod/zodv2"
model_path = '/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/pc-track/zod-full-test_model.pth'
remove_non_foi_tracks = True
remove_non_gt_tracks = True

viz_mini = visualizer.VisualizeResults(conf_path, version, split, result_path, anno_path, data_path, remove_non_foi_tracks, remove_non_gt_tracks)
viz_mini.load_model(model_path)
# Out:
# /datasets/zod/zodv2
# Initializing ZodData class...
# Loading prediction and ground-truths ...
# 100%|██████████| 180/180 [00:00<00:00, 850196.76it/s]
# 100%|██████████| 1/1 [00:00<00:00, 15650.39it/s]
# Loading data samples
# 100%|██████████| 1/1 [00:00<00:00, 24.90it/s]
# Finished loading 2 data samples!
# Succefully loaded model zod-full-test_model.pth

# %%
track_index = 0
frame_track_index = 20
viz_mini.plot_track_index(track_index, frame_track_index, show_lidar=True, show_det=True, show_ref=True, show_gt=False, score_thresh=0.0)
# Out:
# Showing track {'sequence_id': '000000', 'tracking_id': 'Vehicle_0_10', 'starting_frame_index': 70, 'track_length': 32, 'foi_index': 88, 'assoc_metric': 'giou', 'assoc_thresh': 0.0, 'has_gt': True, 'gt_dist': tensor(0.7945, dtype=torch.float64)}
# 90 78 102
# torch.Size([1, 25, 9]) torch.Size([1, 25, 1000, 4])
# torch.Size([25, 1, 3]) torch.Size([25, 3]) torch.Size([25, 1, 2]) torch.Size([25, 1, 1])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 3
#       1 track_index = 0
#       2 frame_track_index = 20
# ----> 3 viz_mini.plot_track_index(track_index, frame_track_index, show_lidar=True, show_det=True, show_ref=True, show_gt=False, score_thresh=0.0)
#
# File ~/workspace/thesis-autoann/Visualizer/visualizer/visualizer.py:71, in VisualizeResults.plot_track_index(self, track_index, frame_track_index, show_lidar, show_det, show_ref, show_gt, score_thresh)
#      68     image = self._add_box_to_image(image, track_box3d, seq, color=self.det_color, line_thickness=self.line_thickness)
#      70 if show_ref:
# ---> 71     ref_box, score = self._get_refined_box(self.trained_model, self.track_data, track_index, frame_track_index, seq, score_thresh)
#      72     if ref_box:
#      73         image = self._add_box_to_image(image, ref_box, seq, color=self.ref_color, line_thickness=self.line_thickness)
#
# File ~/workspace/thesis-autoann/Visualizer/visualizer/visualizer.py:220, in VisualizeResults._get_refined_box(self, model, track_data, track_index, frame_track_index, seq, score_thresh)
#     217 if score < score_thresh:
#     218     return (None, score)
# --> 220 model_out = torch.cat((c_hat[mid_wind], s_hat, r_hat[mid_wind], score_out[mid_wind]), dim=-1).squeeze().detach()
#     221 #unnormalize
#     222 for transformation in reversed(self.transformations):
#
# IndexError: index 13 is out of bounds for dimension 0 with size 1

# %% [markdown]
# ### Full - Train

# %%
import importlib
import visualizer
importlib.reload(visualizer)
import visualizer

conf_path = '/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/pc-track/config.yaml'
version = 'full'
split = "train"
result_path = f"/staging/agp/masterthesis/2023autoann/storage/tracking/SimpleTrack_zod_{version}_{split}/results/Vehicle/results_lidar.json"
anno_path = '/staging/agp/masterthesis/2023autoann/storage/annotations.json'
data_path = "/datasets/zod/zodv2"
model_path = '/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/pc-track/w25-sw-trans-scorew1-lr1-4-rotnorm-e100_model.pth'
remove_non_foi_tracks = True
remove_non_gt_tracks = True

viz = visualizer.VisualizeResults(conf_path, version, split, result_path, anno_path, data_path, remove_non_foi_tracks, remove_non_gt_tracks)
viz.load_model(model_path)
# Out:
# /datasets/zod/zodv2
# Initializing ZodData class...
# Loading train sequences:   0%|          | 0/1165 [00:00<?, ?it/s]
# Loading val sequences:   0%|          | 0/294 [00:00<?, ?it/s]
# Loading prediction and ground-truths ...
# 100%|██████████| 209945/209945 [00:00<00:00, 1556855.70it/s]
# 100%|██████████| 1165/1165 [00:00<00:00, 33184.81it/s]
# Loading data samples
# 100%|██████████| 1165/1165 [04:22<00:00,  4.43it/s]
# Finished loading 7798 data samples!
# Succefully loaded model w25-sw-trans-scorew1-lr1-4-rotnorm-e100_model.pth

# %%
### Load new model ###
model_path = '/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/pc-track/w25-no-sw-oldanno_model.pth'
viz.load_model(model_path)
# Out:
# Succefully loaded model w25-no-sw-oldanno_model.pth

# %%
track_index = 3800
frame_track_index = 89
viz.plot_track_index(track_index, frame_track_index, show_lidar=True, show_det=True, show_ref=True, show_gt=False, score_thresh=0.0)

#interesting: 1199, 7001 (28)
# Out:
# Showing track {'sequence_id': '001255', 'tracking_id': 'Vehicle_1004_1', 'starting_frame_index': 0, 'track_length': 107, 'foi_index': 89, 'assoc_metric': 'giou', 'assoc_thresh': 0.0, 'has_gt': True, 'gt_dist': tensor(0.5373, dtype=torch.float64)}
# box_lidar [5.29640761543171, 12.792870963009573, -1.372906408866383]
# box_camera [ 5.63580563  0.86427931 11.78888921]
# 89 65 113
# Ref_lidar [ 5.4010363 12.023392  -1.2266675]
# Ref_camera [ 5.72132124  0.71447831 11.01773553]

# %%
seq_id = '001255'
out_dir = '/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/viz'
gif_name = f'sequence_tracks_{seq_id}_new.gif'
step = 2
duration = 400
show_lidar = False
show_det = True
show_ref = True
show_gt = False

viz.generate_sequence_gif(seq_id, out_dir, gif_name, step, duration, show_lidar, show_det, show_ref, show_gt)
# Out:
# Found 2 number of tracks in sequence
# box_lidar [-14.529705047607434, 28.32803153991701, -1.6634828448295602]
# box_camera [-13.78495574   1.14020288  27.82816245]
# 0 -24 24
# Ref_lidar [-14.457779   28.871048   -1.6792556]
# Ref_camera [-13.69915244   1.15920459  28.3690559 ]
# box_lidar [-7.024017333984377, 19.830499649047866, -1.5373785495758066]
# box_camera [-6.50000588  1.00578186 19.14077302]
# 0 -24 24
# Ref_lidar [-7.018894 20.40579  -1.614551]
# Ref_camera [-6.48046018  1.08602591 19.71533377]
# box_lidar [-14.148998445230953, 28.124121586301705, -1.7911361428835697]
# box_camera [-13.41027187   1.26863433  27.61385075]
# 2 -22 26
# Ref_lidar [-14.147579   28.722412   -1.7780174]
# Ref_camera [-13.3933828    1.25869335  28.21196579]
# box_lidar [-6.897574410766094, 19.689237645811154, -1.5977984789226325]
# box_camera [-6.37754725  1.06607007 18.99598853]
# 2 -22 26
# Ref_lidar [-6.884387  20.3234    -1.6377088]
# Ref_camera [-6.348237    1.10940441 19.62938596]
# box_lidar [-14.123255457686302, 28.18380890888459, -1.827284007822743]
# box_camera [-13.38318263   1.30522346  27.67266703]
# 4 -20 28
# Ref_lidar [-14.103942   28.838356   -1.7750237]
# Ref_camera [-13.34676025   1.25652757  28.32676044]
# box_lidar [-6.836468388031615, 19.70191003400392, -1.615030035489974]
# box_camera [-6.31622258  1.0836672  19.00699252]
# 4 -20 28
# Ref_lidar [-6.8498344 20.33421   -1.6118294]
# Ref_camera [-6.31328795  1.08375198 19.63943447]
# box_lidar [-14.08924102874609, 28.266030641913495, -1.8238648619003346]
# box_camera [-13.34704573   1.30240648  27.75400137]
# 6 -18 30
# Ref_lidar [-14.150529   28.859531   -1.7741698]
# Ref_camera [-13.39278171   1.25555806  28.34913362]
# box_lidar [-6.793042650407853, 19.688353778380037, -1.5379766793177345]
# box_camera [-6.27277356  1.00675641 18.99272021]
# 6 -18 30
# Ref_lidar [-6.8086205 20.311016  -1.5613353]
# Ref_camera [-6.27243153  1.03333789 19.61544803]
# box_lidar [-14.10101410035532, 28.30737174969072, -1.826307523233779]
# box_camera [-13.35776261   1.30501057  27.79561899]
# 8 -16 32
# Ref_lidar [-14.122888   28.844164   -1.7411361]
# Ref_camera [-13.36537957   1.22257894  28.33322985]
# box_lidar [-6.778956305466378, 19.636384451965867, -1.5125819309865909]
# box_camera [-6.25990251  0.98115582 18.94053712]
# 8 -16 32
# Ref_lidar [-6.8025465 20.247084  -1.5433612]
# Ref_camera [-6.26791542  1.01505513 19.55147412]
# box_lidar [-14.139493882712133, 28.384300657048538, -1.8007858227405045]
# box_camera [-13.39412016   1.279709    27.87364504]
# 10 -14 34
# Ref_lidar [-14.233583   28.864971   -1.7106899]
# Ref_camera [-13.47534857   1.19170241  28.35704037]
# box_lidar [-6.742271970118826, 19.571770943487238, -1.4861841051262015]
# box_camera [-6.22476175  0.9545957  18.87513698]
# 10 -14 34
# Ref_lidar [-6.775345  20.187204  -1.5540596]
# Ref_camera [-6.24231863  1.02556902 19.4908591 ]
# box_lidar [-14.214918787074105, 28.392802177533127, -1.7638827359240916]
# box_camera [-13.46911475   1.24248302  27.88427842]
# 12 -12 36
# Ref_lidar [-14.183997   28.961449   -1.6907083]
# Ref_camera [-13.42319487   1.17247509  28.45230987]
# box_lidar [-6.772014131073232, 19.549917125550614, -1.4697331686624264]
# box_camera [-6.25497367  0.93788391 18.85414234]
# 12 -12 36
# Ref_lidar [-6.752817 20.264175 -1.518554]
# Ref_camera [-6.21763844  0.99058236 19.56740656]
# box_lidar [-14.078725094945868, 28.618157925394918, -1.8300088735762414]
# box_camera [-13.32749797   1.31046777  28.10570416]
# 14 -10 38
# Ref_lidar [-14.098654   29.090347   -1.8219317]
# Ref_camera [-13.33522161   1.3047956   28.57828576]
# box_lidar [-6.731245947415117, 19.624034757922388, -1.5031569164538316]
# box_camera [-6.21247917  0.97189896 18.92701078]
# 14 -10 38
# Ref_lidar [-6.779434 20.368248 -1.600901]
# Ref_camera [-6.24198061  1.07334858 19.67170332]
# box_lidar [-14.049837335928164, 28.728983017790352, -1.8906718976183938]
# box_camera [-13.29607159   1.3718578   28.21543271]
# 16 -8 40
# Ref_lidar [-14.061003   29.43909    -1.9176099]
# Ref_camera [-13.28908517   1.40250355  28.92544349]
# box_lidar [-6.774742656302918, 19.661790329476542, -1.5385155096343368]
# box_camera [-6.25516651  1.00724396 18.9656915 ]
# 16 -8 40
# Ref_lidar [-6.834832  20.621897  -1.6579443]
# Ref_camera [-6.29111545  1.1314636  19.92639722]
# box_lidar [-13.997174874671765, 29.04261952940429, -1.933960689575917]
# box_camera [-13.23556952   1.41706507  28.52737969]
# 18 -6 42
# Ref_lidar [-14.045645   29.637943   -1.9282423]
# Ref_camera [-13.268666     1.41426455  29.12377651]
# box_lidar [-6.76208260533367, 19.692924535788052, -1.558629065191512]
# box_camera [-6.24181029  1.0275839  18.99638464]
# 18 -6 42
# Ref_lidar [-6.7854595 20.958843  -1.6938621]
# Ref_camera [-6.23326483  1.16940747 20.26176903]
# box_lidar [-13.950542220111375, 29.29311321703589, -1.9736031534883378]
# box_camera [-13.18270262   1.45826201  28.77637993]
# 20 -4 44
# Ref_lidar [-13.973501   29.928154   -1.9910158]
# Ref_camera [-13.18939063   1.47892713  29.41170294]
# box_lidar [-6.740764321107096, 19.718230859726106, -1.622692129981196]
# box_camera [-6.22016974  1.09188368 19.02080148]
# 20 -4 44
# Ref_lidar [-6.7743063 21.351685  -1.7869502]
# Ref_camera [-6.21246869  1.26462951 20.65370575]
# box_lidar [-13.870640462215475, 29.651058957073438, -1.9467481504904711]
# box_camera [-13.09347725   1.43369535  29.13228153]
# 22 -2 46
# Ref_lidar [-13.7568035  30.330732   -1.8804306]
# Ref_camera [-12.96184641   1.37153803  29.80912906]
# box_lidar [-6.713424291332034, 19.821598624384812, -1.682747571224827]
# box_camera [-6.19047952  1.15261905 19.1231183 ]
# 22 -2 46
# Ref_lidar [-6.7002    21.823689  -1.8441095]
# Ref_camera [-6.12652243  1.32465104 21.12334103]
# box_lidar [-13.621079768589794, 30.05346126344844, -1.9498500682448596]
# box_camera [-12.83365726   1.44015021  29.52809674]
# 24 0 48
# Ref_lidar [-13.661646   32.172646   -2.1390371]
# Ref_camera [-12.82059697   1.64036401  31.64661588]
# box_lidar [-6.6151197607498124, 20.118327443541435, -1.679149378410278]
# box_camera [-6.08455076  1.15107419 19.41722956]
# 24 0 48
# Ref_lidar [-6.620777  22.304409  -1.8547916]
# Ref_camera [-6.03480324  1.33826878 21.6017932 ]
# box_lidar [-13.447566665239556, 30.552174521801305, -2.071683629280203]
# box_camera [-12.64797567   1.56547206  30.0215356 ]
# 26 2 50
# Ref_lidar [-13.3692465  32.575768   -2.0345488]
# Ref_camera [-12.51739374   1.53944472  32.0426028 ]
# box_lidar [-6.405356339661572, 20.50911615783493, -1.7307125163958634]
# box_camera [-5.86505693  1.20573283 19.80221029]
# 26 2 50
# Ref_lidar [-6.469798  22.707058  -1.8309144]
# Ref_camera [-5.87338903  1.31726431 22.00053524]
# box_lidar [-13.13271674418597, 31.083502214645627, -1.9542989639310013]
# box_camera [-12.31896388   1.45244601  30.54517203]
# 28 4 52
# Ref_lidar [-13.076707   33.346733   -1.9581184]
# Ref_camera [-12.2047204    1.46853273  32.80615751]
# box_lidar [-6.182861166753255, 20.681364269389817, -1.6657939940802045]
# box_camera [-5.63787713  1.142817   19.96900017]
# 28 4 52
# Ref_lidar [-6.187833  23.140575  -1.8108289]
# Ref_camera [-5.58025796  1.30085578 22.42673959]
# box_lidar [-12.798421757739135, 31.79705486307973, -1.920574187975522]
# box_camera [-11.96624239   1.42413844  31.25003663]
# 30 6 54
# Ref_lidar [-12.633604   34.347565   -1.8777602]
# Ref_camera [-11.73559747   1.39564742  33.79563863]
# box_lidar [-5.898150026086064, 21.274857604677766, -1.6651347332804551]
# box_camera [-5.3379798   1.14669535 20.55495389]
# 30 6 54
# Ref_lidar [-5.8548956 23.39918   -1.7839254]
# Ref_camera [-5.24064172  1.27695178 22.67681253]
# box_lidar [-12.276690613237514, 32.60450983751769, -1.740567536345921]
# box_camera [-11.42299631   1.25096716  32.04469677]
# 32 8 56
# Ref_lidar [-11.971928   35.048157   -1.7594613]
# Ref_camera [-11.05551586   1.28430047  34.47954679]
# box_lidar [-5.62484175178828, 21.740864107535934, -1.6277607653679604]
# box_camera [-5.05257934  1.11312858 21.01394859]
# 32 8 56
# Ref_lidar [-5.48468   24.031918  -1.6428624]
# Ref_camera [-4.85355345  1.14105623 23.30051983]
# box_lidar [-11.596266749022229, 33.42025876335401, -1.7409877458394374]
# box_camera [-10.72180539   1.25903816  32.84262488]
# 34 10 58
# Ref_lidar [-11.354889   35.832542   -1.7619665]
# Ref_camera [-10.41850627   1.29398018  35.24774535]
# box_lidar [-5.083889228524795, 22.298452048747365, -1.602478364939957]
# box_camera [-4.49732953  1.09344744 21.55753248]
# 34 10 58
# Ref_lidar [-4.9362183 24.261782  -1.678462 ]
# Ref_camera [-4.29954083  1.18055553 23.51598476]
# box_lidar [-10.822846040500648, 34.26555869384783, -1.694871768321964]
# box_camera [-9.92665489  1.22118564 33.66793761]
# 36 12 60
# Ref_lidar [-10.574294   36.34182    -1.6295508]
# Ref_camera [-9.62440205  1.16808465 35.73741301]
# box_lidar [-4.572808946866476, 22.880663307751792, -1.5516654348560635]
# box_camera [-3.97117939  1.0482208  22.12663312]
# 36 12 60
# Ref_lidar [-4.34038   24.575686  -1.6247746]
# Ref_camera [-3.69555581  1.13144718 23.81470105]
# box_lidar [-9.914329496174725, 35.20288890995564, -1.4866228792912182]
# box_camera [-8.99327065  1.02235287 34.58260544]
# 38 14 62
# Ref_lidar [-9.426549  36.744774  -1.4448774]
# Ref_camera [-8.46574879  0.99116501 36.11160176]
# box_lidar [-3.913062555409662, 23.35195109831662, -1.4951864967691084]
# box_camera [-3.2992418   0.99746763 22.58104631]
# 38 14 62
# Ref_lidar [-3.5539737 24.952251  -1.569677 ]
# Ref_camera [-2.89944746  1.08219287 24.17115352]
# box_lidar [-8.821021126396925, 36.04883907360178, -1.3610143306719218]
# box_camera [-7.87792631  0.90657786 35.40073472]
# 40 16 64
# Ref_lidar [-8.232225  37.146305  -1.3337259]
# Ref_camera [-7.26093929  0.88798571 36.48278742]
# box_lidar [-3.044375385104624, 23.815985490788346, -1.472988748945387]
# box_camera [-2.41879439  0.98197825 23.02264624]
# 40 16 64
# Ref_lidar [-2.7458422 25.09951   -1.6150382]
# Ref_camera [-2.08803059  1.13228579 24.29729862]
# box_lidar [-7.528343693007539, 36.86440502165422, -1.0734023136777102]
# box_camera [-6.56324961  0.6296177  36.1841897 ]
# 42 18 66
# Ref_lidar [-6.966383  37.952637  -0.8013692]
# Ref_camera [-5.97209605  0.36610701 37.25896859]
# box_lidar [-2.2577134970969763, 24.20673490590782, -1.3362109503977695]
# box_camera [-1.62165506  0.85112225 23.39369312]
# 42 18 66
# Ref_lidar [-1.8998256 25.401623  -1.3448148]
# Ref_camera [-1.2331684   0.86780828 24.57889964]
# box_lidar [-6.246353867661466, 37.62944136216574, -0.5661101453028659]
# box_camera [-5.25945376  0.13266306 36.91854406]
# 44 20 68
# Ref_lidar [-5.6909847  39.084206   -0.85180104]
# Ref_camera [-4.66825535  0.42877199 38.35701449]
# box_lidar [-1.4069338786331262, 24.48020268495413, -1.0088274263111918]
# box_camera [-0.76248178  0.52935759 23.64683208]
# 44 20 68
# Ref_lidar [-0.98913485 25.76234    -1.4312695 ]
# Ref_camera [-0.31393809  0.96062651 24.91557419]
# box_lidar [-4.938337784000746, 38.267536992523176, -1.1131550946999818]
# box_camera [-3.93820798  0.68947273 37.5198783 ]
# 46 22 70
# Ref_lidar [-4.3410397 39.814037  -1.0450387]
# Ref_camera [-3.30095486  0.63247477 39.05080216]
# box_lidar [-0.5217949140550342, 24.60848987373524, -1.4128021297644762]
# box_camera [ 0.12362528  0.93833084 23.75017287]
# 46 22 70
# Ref_lidar [-0.10961139 25.254444   -1.6409856 ]
# Ref_camera [ 0.5511517   1.17194744 24.38410054]
# box_lidar [-3.425981106193127, 38.99166499936948, -0.8045265329716504]
# box_camera [-2.4061763   0.39208648 38.20637377]
# 48 24 72
# Ref_lidar [-2.7216053 40.009354  -0.7513738]
# Ref_camera [-1.67557303  0.34777324 39.20583154]
# box_lidar [0.4310972259491096, 24.698157380341648, -1.3150511636773585]
# box_camera [ 1.07898946  0.84571819 23.81575576]
# 48 24 72
# Ref_lidar [ 0.9140328 25.180798  -1.5703017]
# Ref_camera [ 1.57290267  1.10588171 24.28446232]
# box_lidar [-1.832069521820618, 39.63280772832795, -0.767866231980061]
# box_camera [-0.79612132  0.36662054 38.80640422]
# 50 26 74
# Ref_lidar [-1.2867486 40.549515  -0.7794807]
# Ref_camera [-0.22744375  0.38575972 39.70867971]
# box_lidar [1.3836904066996938, 24.70296424679321, -1.3112442955672408]
# box_camera [ 2.0313977   0.84659604 23.79602921]
# 50 26 74
# Ref_lidar [ 1.8322046 25.052305  -1.6410955]
# Ref_camera [ 2.48709431  1.18048362 24.13198397]
# box_lidar [-0.4595607760822408, 40.10093466277404, -0.797994116026331]
# box_camera [ 0.58781667  0.40594132 39.23883954]
# 52 28 76
# Ref_lidar [ 0.16138816 40.87362    -0.70274556]
# Ref_camera [ 1.22892515  0.31782694 39.99574564]
# box_lidar [2.1728032731079034, 24.61245487474628, -1.3036684481652112]
# box_camera [ 2.8179467   0.84240032 23.68525228]
# 52 28 76
# Ref_lidar [ 2.5229065 24.885399  -1.5230572]
# Ref_camera [ 3.17385442  1.06494214 23.94794408]
# box_lidar [0.8147395663508221, 40.49246512382054, -0.6034291011317493]
# box_camera [ 1.87273718  0.2196888  39.59839801]
# 54 30 78
# Ref_lidar [ 1.4188399 41.112698  -0.375418 ]
# Ref_camera [ 2.49374492e+00 -2.07494817e-03  4.02040257e+01]
# box_lidar [2.8294867365068694, 24.408829166367063, -1.1706422441915305]
# box_camera [ 3.46982993  0.71151036 23.46546   ]
# 54 30 78
# Ref_lidar [ 3.101608  24.560513  -1.2300847]
# Ref_camera [ 3.74546426  0.77308599 23.6097701 ]
# box_lidar [2.1168660391293295, 40.844843947533185, -0.22733282373174335]
# box_camera [ 3.18537855 -0.14816165 39.91903998]
# 56 32 80
# Ref_lidar [ 2.6880498  41.5048     -0.17045063]
# Ref_camera [ 3.77364368 -0.19875144 40.56433976]
# box_lidar [3.3724222406441755, 24.175607070271564, -0.9873141980329151]
# box_camera [ 4.00749513  0.52960669 23.21927335]
# 56 32 80
# Ref_lidar [ 3.5730636 24.14846   -1.1063457]
# Ref_camera [ 4.20677025  0.64947253 23.1863493 ]
# box_lidar [3.2722885794518444, 41.09019975021216, -0.281838437140308]
# box_camera [ 4.34644676 -0.08670606 40.13425011]
# 58 34 82
# Ref_lidar [ 3.6582305  41.86111    -0.41486067]
# Ref_camera [ 4.75143622  0.05228559 40.89425974]
# box_lidar [3.756006592154935, 23.760237753849875, -1.0856197307225535]
# box_camera [ 4.37975875  0.62758464 22.79365296]
# 58 34 82
# Ref_lidar [ 3.9378474 23.717632  -1.2669153]
# Ref_camera [ 4.55952881  0.80953913 22.74543803]
# box_lidar [4.188473955642138, 41.31594643837966, -0.63285023530109]
# box_camera [ 5.26636505  0.26997397 40.33449044]
# 60 36 84
# Ref_lidar [ 4.5921135 41.94167   -0.5120733]
# Ref_camera [ 5.68658337  0.15449021 40.95021873]
# box_lidar [4.1679417009537865, 23.436171091059823, -1.2791337672793637]
# box_camera [ 4.78223567  0.82139112 22.45808062]
# 60 36 84
# Ref_lidar [ 4.2860985 23.133362  -1.3114008]
# Ref_camera [ 4.89239309  0.85263054 22.15216383]
# box_lidar [5.0341039333700826, 41.48730160083318, -0.600674909720947]
# box_camera [ 6.11627765  0.24284352 40.48415814]
# 62 38 86
# Ref_lidar [ 5.573941 42.028984 -0.519113]
# Ref_camera [ 6.67028594  0.16679459 41.01216184]
# box_lidar [4.380093035154863, 22.93500007878269, -1.305174995225106]
# box_camera [ 4.98127931  0.84581348 21.95148028]
# 62 38 86
# Ref_lidar [ 4.54758  22.599857 -1.344887]
# Ref_camera [ 5.13987979  0.88456765 21.6119313 ]
# box_lidar [6.027664815075331, 41.65511993348294, -0.6349547246552071]
# box_camera [ 7.11364518  0.28287127 40.62613389]
# 64 40 88
# Ref_lidar [ 6.40891    42.059532   -0.63189214]
# Ref_camera [ 7.50518687  0.28381652 41.02059628]
# box_lidar [4.656148901255982, 22.553562134120618, -1.402306330664933]
# box_camera [ 5.246931    0.94227116 21.56255697]
# 64 40 88
# Ref_lidar [ 4.8587484 22.023006  -1.3698158]
# Ref_camera [ 5.43596372  0.90796088 21.02713099]
# box_lidar [6.83686614304816, 41.77771954869539, -0.6921938588873648]
# box_camera [ 7.92543695  0.34471642 40.72753936]
# 66 42 90
# Ref_lidar [ 7.167053  42.209206  -0.6309963]
# Ref_camera [ 8.26692757  0.28742193 41.15068282]
# box_lidar [4.931449706277199, 21.996492514112386, -1.4512846382135316]
# box_camera [ 5.50754786  0.98964265 20.99833116]
# 66 42 90
# Ref_lidar [ 4.9879007 21.240545  -1.372259 ]
# Ref_camera [ 5.54491303  0.90688925 20.2415989 ]
# box_lidar [7.511718160375116, 41.94634094882534, -0.6382801267826489]
# box_camera [ 8.60466923  0.29499836 40.87898816]
# 68 44 92
# Ref_lidar [ 7.7466927 42.37439   -0.6036983]
# Ref_camera [ 8.85075776  0.26383504 41.30101172]
# box_lidar [4.979996012648227, 21.324152485340402, -1.4476622233487935]
# box_camera [ 5.53878472  0.98269488 20.32499101]
# 68 44 92
# Ref_lidar [ 5.139166 20.68401  -1.381315]
# Ref_camera [ 5.6817513   0.91373561 19.68131007]
# box_lidar [8.155264076926866, 42.01292303789906, -0.6268536158111815]
# box_camera [ 9.2497654   0.28707257 40.92902005]
# 70 46 94
# Ref_lidar [ 8.397491  42.398407  -0.5990844]
# Ref_camera [ 9.50197416  0.26253157 41.30827141]
# box_lidar [5.186550397842353, 20.86948740536884, -1.4478597705510925]
# box_camera [ 5.73356062  0.98149331 19.86515844]
# 70 46 94
# Ref_lidar [ 5.2937517 20.214062  -1.4045362]
# Ref_camera [ 5.82406734  0.93522198 19.20742038]
# box_lidar [8.753455636896177, 42.125873566166625, -0.4949707686168606]
# box_camera [ 9.8513221   0.15871747 41.02719623]
# 72 48 96
# Ref_lidar [ 9.008021  42.3402    -0.5201748]
# Ref_camera [10.11119182  0.18630169 41.23475578]
# box_lidar [5.241747164176224, 20.326051661576003, -1.4181249727880725]
# box_camera [ 5.77489583  0.94914945 19.32064166]
# 72 48 96
# Ref_lidar [ 5.2809944 19.503517  -1.3498597]
# Ref_camera [ 5.79329462  0.87671913 18.49773289]
# box_lidar [9.067446449371658, 42.1864582853745, -0.4262579668240082]
# box_camera [10.16711009  0.09186324 41.08002279]
# 74 50 98
# Ref_lidar [ 9.306482   42.45832    -0.46036065]
# Ref_camera [10.41289201  0.12857483 41.34545408]
# box_lidar [5.298574455826374, 19.61612874254742, -1.371883941403874]
# box_camera [ 5.81365737  0.89942552 18.60973857]
# 74 50 98
# Ref_lidar [ 5.42091  18.911266 -1.363069]
# Ref_camera [ 5.91784668  0.88747398 17.90201233]
# box_lidar [9.610166411153559, 42.32576569339617, -0.3586131682456577]
# box_camera [1.07135700e+01 2.76128763e-02 4.12056442e+01]
# 76 52 100
# Ref_lidar [ 9.738631   42.551125   -0.33722663]
# Ref_camera [1.08479005e+01 8.04944660e-03 4.14277249e+01]
# box_lidar [5.377425641145914, 18.899138013756776, -1.3348215724230958]
# box_camera [ 5.87420711  0.85895027 17.89115502]
# 76 52 100
# Ref_lidar [ 5.427393  18.236341  -1.3091104]
# Ref_camera [ 5.90722123  0.82997185 17.22743267]
# box_lidar [9.846060361604572, 42.374252864501294, -0.26873495334678166]
# box_camera [10.95108294 -0.0608523  41.24849968]
# 78 54 102
# Ref_lidar [ 9.943504  42.453846  -0.2758446]
# Ref_camera [11.05050695 -0.05284445 41.32551707]
# box_lidar [5.367917731777717, 18.20002404579596, -1.2541766486177046]
# box_camera [ 5.84710748  0.77455617 17.19294475]
# 78 54 102
# Ref_lidar [ 5.363534  17.614788  -1.2248191]
# Ref_camera [ 5.82780453  0.74207661 16.6081758 ]
# box_lidar [9.952964306076554, 42.5718578816, -0.33476021980376724]
# box_camera [1.10627061e+01 6.74127796e-03 4.14429397e+01]
# 80 56 104
# Ref_lidar [ 9.917684  42.783497  -0.3874848]
# Ref_camera [11.03262163  0.06041344 41.65514217]
# box_lidar [5.288340017866731, 17.325980979060652, -1.2987862227287714]
# box_camera [ 5.7448287   0.81414361 16.321024  ]
# 80 56 104
# Ref_lidar [ 5.236017  16.503147  -1.0473663]
# Ref_camera [ 5.67260177  0.55811389 15.50112323]
# box_lidar [9.837931685818731, 42.86970981904766, -0.4919117747828523]
# box_camera [10.95459208  0.16490451 41.74284077]
# 82 58 106
# Ref_lidar [ 9.905889  43.056652  -0.6037374]
# Ref_camera [11.02677679  0.27805027 41.92738864]
# box_lidar [5.210472745027965, 16.22829635515822, -1.2717289154872473]
# box_camera [ 5.63886179  0.78088927 15.22586551]
# 82 58 106
# Ref_lidar [ 5.243436  15.882585  -1.1130931]
# Ref_camera [ 5.6637097   0.62058683 14.88024401]
# box_lidar [9.892238824047096, 43.036777282565076, -0.8266456669376423]
# box_camera [11.01149972  0.50078064 41.90671976]
# 84 60 108
# Ref_lidar [ 9.75522   43.248886  -1.2102175]
# Ref_camera [10.8780619   0.88479633 42.12030306]
# box_lidar [5.249086625004351, 15.48176795507727, -1.367297869464589]
# box_camera [ 5.65776097  0.87268857 14.47810564]
# 84 60 108
# Ref_lidar [ 5.2150307 15.011988  -1.2566577]
# Ref_camera [ 5.61217722  0.75939525 14.00993762]
# box_lidar [9.315914262130164, 43.34355323159307, -1.192053397462895]
# box_camera [10.44143565  0.86498574 42.22635376]
# 86 62 110
# Ref_lidar [ 9.056055  43.40967   -1.3956696]
# Ref_camera [10.18234491  1.06767603 42.29809389]
# box_lidar [5.159475255199049, 14.395330232039315, -1.3719614659159267]
# box_camera [ 5.54018415  0.87115646 13.39432881]
# 86 62 110
# Ref_lidar [ 5.2201986 13.801489  -1.2240514]
# Ref_camera [ 5.5863402   0.72040029 12.79989254]
# box_lidar [8.94352295732105, 43.53456233975281, -1.3461746502686955]
# box_camera [10.07331588  1.01829382 42.42609757]
# 88 64 112
# Ref_lidar [ 8.778899  43.550285  -1.4458126]
# Ref_camera [ 9.90865282  1.1172073  42.44554275]
# box_lidar [5.2859772524962985, 13.42857038505556, -1.3825881868722631]
# box_camera [ 5.64169775  0.87727854 12.42458772]
# 88 64 112
# Ref_lidar [ 5.3271694 12.572881  -1.2066741]
# Ref_camera [ 5.66172816  0.697036   11.56904185]
# box_lidar [8.444556925656142, 43.74070176803639, -1.4047421577841108]
# box_camera [ 9.57953475  1.07551173 42.64472287]
# 90 66 114
# Ref_lidar [ 8.200611 43.765583 -1.44799 ]
# Ref_camera [ 9.33609616  1.1176971  42.67565917]
# box_lidar [5.3714766670349805, 12.24171812351686, -1.3570518391110773]
# box_camera [ 5.69673783  0.84587163 11.23607405]
# 90 66 114
# Ref_lidar [ 5.454179  11.506149  -1.2676017]
# Ref_camera [ 5.76092216  0.75293039 10.49909049]
# box_lidar [7.787068330166044, 43.88381137170324, -1.6140094275097683]
# box_camera [ 8.92490536  1.28231615 42.80364643]
# 92 68 116
# Ref_lidar [ 7.5234146 43.983246  -1.9569317]
# Ref_camera [ 8.66217905  1.6244669  42.90806835]
# box_lidar [5.591043859870184, 11.085172946786418, -1.4217468789014007]
# box_camera [ 5.88612639  0.90551008 10.073935  ]
# 92 68 116
# Ref_lidar [ 5.7366686 10.428921  -1.4030919]
# Ref_camera [6.01489803 0.88409021 9.41425282]
# box_lidar [7.0658118671487085, 44.16362848352625, -2.254058213528548]
# box_camera [ 8.20788483  1.92030343 43.09864598]
# 94 70 118
# Ref_lidar [ 6.914875  44.05726   -2.3575592]
# Ref_camera [ 8.05374101  2.02249982 42.99566775]
# box_lidar [6.005713288015987, 9.802008371634038, -1.6073722267181636]
# box_camera [6.26668214 1.08635897 8.77956649]
# 94 70 118
# Ref_lidar [ 6.193243   9.168558  -1.2496729]
# Ref_camera [6.43963547 0.72622934 8.14335172]
# box_lidar [6.6885665293079235, 44.225930964832884, -2.5393600565020558]
# box_camera [ 7.83093954  2.2040829  43.16917435]
# 96 72 120
# Ref_lidar [ 6.6074553 44.125084  -2.345056 ]
# Ref_camera [ 7.74823619  2.00885282 43.0714575 ]
# box_lidar [6.441691140038845, 8.453100131255573, -1.6068993808543444]
# box_camera [6.66778158 1.08087032 7.41989025]
# 96 72 120
# Ref_lidar [ 6.69366    7.7836776 -1.3309604]
# Ref_camera [6.90381452 0.80262347 6.74563198]
# box_lidar [6.261687219079932, 44.293204107336344, -2.5882699506410445]
# box_camera [ 7.40569343  2.25126014 43.24717338]
# 98 74 122
# Ref_lidar [ 6.1106815 44.283936  -2.5875707]
# Ref_camera [ 7.25450458  2.24977319 43.24180355]
# box_lidar [6.96101327502949, 6.897229225991793, -1.523469460528787]
# box_camera [7.14728481 0.99173766 5.85160383]
# 98 74 122
# Ref_lidar [ 7.2271824  6.279231  -1.3454382]
# Ref_camera [7.3983453  0.81173799 5.22787986]
# box_lidar [5.875618516077265, 44.45771056276255, -2.495436433250163]
# box_camera [ 7.02445976  2.15741253 43.42205333]
# 100 76 124
# Ref_lidar [ 5.465498 44.51004  -2.450264]
# Ref_camera [ 6.61605474  2.11051265 43.48516872]
# box_lidar [7.530434716908052, 5.55156978821973, -1.4641415409637852]
# box_camera [7.68216136 0.92806536 4.49204036]
# 100 76 124
# Ref_lidar [ 7.936572   5.0218983 -1.3001251]
# Ref_camera [8.07534566 0.76323278 3.95293259]
# box_lidar [4.941291311694845, 44.62108457560387, -2.4763106983538186]
# box_camera [ 6.09475667  2.13458324 43.60955046]
# 102 78 126
# Ref_lidar [ 4.4381704 44.50891   -2.3940215]
# Ref_camera [ 5.58933435  2.04924099 43.51080841]
# box_lidar [8.317104444540494, 4.1640022109788015, -1.3336679695883533]
# box_camera [8.43348998 0.79408975 3.08535196]
# 102 78 126
# Ref_lidar [ 6.702508   3.0034447 -1.1454805]
# Ref_camera [6.79051375 0.5918601  1.96778211]
# box_lidar [4.198272039449733, 44.66011040201752, -2.44270852372545]
# box_camera [ 5.3531668   2.09755463 43.66788661]
# 104 80 128
# Ref_lidar [ 3.7737896 44.687355  -2.6826694]
# Ref_camera [ 4.92832595  2.3355775  43.70482118]
# box_lidar [8.590781475784912, 2.891596038640769, -1.3390846696559051]
# box_camera [8.67428457 0.79410208 1.80630392]
# 104 80 128
# Ref_lidar [ 3.0369928  4.8844175 -1.2067659]
# Ref_camera [3.17438203 0.64518352 3.94226035]
# box_lidar [3.3599967124521957, 44.89764611425041, -2.8927273799718187]
# box_camera [ 4.51903412  2.54472053 43.92461807]
# 106 82 130
# Ref_lidar [ 2.925292 44.77604  -2.880532]
# Ref_camera [ 4.08140927  2.52975492 43.81431993]
# box_lidar [8.845479335211056, 1.6164156635881148, -1.3216919544173344]
# box_camera [8.89614973 0.77119807 0.52508975]
# 106 82 130
# Ref_lidar [ 3.6082647  4.592454  -1.0757185]
# Ref_camera [3.73859867 0.51538647 3.63635183]
# box_lidar [2.3426572516547575, 44.97867847209315, -2.7348906823113035]
# box_camera [ 3.50492441  2.38234152 44.03265884]
# 108 84 132
# Ref_lidar [ 1.9544868 45.00171   -2.3822703]
# Ref_camera [ 3.11925281  2.02795384 44.06750938]
# box_lidar [1.4093605984431035, 45.04700667362626, -2.395294971522352]
# box_camera [ 2.575415    2.03855196 44.12677375]
# 110 86 134
# Ref_lidar [ 1.0155289 44.95774   -2.2689965]
# Ref_camera [ 2.18005526  1.90985748 44.04834219]
# box_lidar [0.5902927436488965, 45.08320487926313, -1.8914285364059134]
# box_camera [ 1.76009342  1.53088438 44.18667524]
# 112 88 136
# Ref_lidar [ 0.19483423 44.984642   -1.480614  ]
# Ref_camera [ 1.36429799  1.11762397 44.10046323]
# box_lidar [-0.13197842016906675, 45.014271609578074, -1.663239785045626]
# box_camera [ 1.03744283  1.29880363 44.13756115]
# 114 90 138
# Ref_lidar [-0.28769165 44.914757   -2.0966196 ]
# Ref_camera [ 0.87704282  1.73088323 44.03985273]
# box_lidar [-0.44926558368322267, 44.970014543019005, -2.4311911280470113]
# box_camera [ 0.71526571  2.06494862 44.09752546]
# 116 92 140
# Ref_lidar [-0.51712567 44.185425   -1.842724  ]
# Ref_camera [ 0.63018549  1.47200713 43.31799907]
# box_lidar [-0.7080176580831158, 44.910678861555795, -1.8532097858477223]
# box_camera [ 0.45797983  1.48540231 44.04786819]
# 118 94 142
# Ref_lidar [-0.7692796 44.81446   -1.5524607]
# Ref_camera [ 0.39577315  1.1838515  43.95481757]
# box_lidar [-0.8648550350152472, 44.83483008054082, -1.697619249898656]
# box_camera [ 0.30002551  1.32864679 43.97689247]
# 120 96 144
# Ref_lidar [-0.8524071 44.28438   -1.4709921]
# Ref_camera [ 0.29943561  1.09916945 43.42748564]
# box_lidar [-0.8716427464629156, 44.74060441615003, -1.6062847772383586]
# box_camera [ 0.29127312  1.23678217 43.88334664]
# 122 98 146
# Ref_lidar [-0.8620576 44.16314   -1.4661003]
# Ref_camera [ 0.28669132  1.09358813 43.30655904]
# box_lidar [-0.8973288567645616, 44.64969764211663, -1.5696246086438286]
# box_camera [ 0.26343949  1.19951559 43.79332288]
# 124 100 148
# Ref_lidar [-0.8697151 43.860542  -1.5748547]
# Ref_camera [ 0.27069884  1.20069871 43.00370149]
# box_lidar [-0.8756010840246778, 44.55708329532134, -1.5252783524367375]
# box_camera [ 0.2829981   1.15478597 43.70040988]
# 126 102 150
# Ref_lidar [-0.7157792 43.799957  -1.2775   ]
# Ref_camera [ 0.42451635  0.90378359 42.94070774]
# box_lidar [-0.7373526972015976, 44.53189464402504, -1.1165143481205955]
# box_camera [ 0.42260477  0.74657529 43.67378073]
# 128 104 152
# Ref_lidar [-0.66891617 43.870003   -1.159374  ]
# Ref_camera [ 0.47376041  0.78626102 43.01013208]
# box_lidar [-0.719377642680727, 44.51095558099589, -1.2220598784469363]
# box_camera [ 0.43950406  0.85209503 43.6518398 ]
# 130 106 154
# Ref_lidar [-0.576218  43.578484  -1.2495956]
# Ref_camera [ 0.55846739  0.87538888 42.71585794]
# box_lidar [-0.6209523261132024, 44.465640027795125, -1.160269882297177]
# box_camera [ 0.5370393   0.7905479  43.60432271]
# 132 108 156
# Ref_lidar [-0.58667517 43.75151    -1.0903797 ]
# Ref_camera [ 0.55326901  0.71704286 42.88991808]
# box_lidar [-0.6183309080870628, 44.48143897850699, -1.1314578693899784]
# box_camera [ 0.5402114   0.76183318 43.62019764]
# 134 110 158
# Ref_lidar [-0.6025989 43.877     -1.2563186]
# Ref_camera [ 0.53974775  0.88356451 43.01491526]
# box_lidar [-0.6574280628524348, 44.41765986622662, -1.290466424241501]
# box_camera [ 0.4986864   0.92030839 43.55662592]
# 136 112 160
# Ref_lidar [-0.6644444 43.723656  -1.3693473]
# Ref_camera [ 0.47340731  0.99547524 42.86263448]
# box_lidar [-0.7612675613452249, 44.43614439256681, -1.4391463452913635]
# box_camera [ 0.39461131  1.06857452 43.57701145]
# 138 114 162
# Ref_lidar [-0.71192396 43.74872    -1.4705654 ]
# Ref_camera [ 0.42608066  1.09659131 42.88838864]
# box_lidar [-0.7674125015724793, 44.39798961550869, -1.401239583471278]
# box_camera [ 0.38767662  1.0304365  43.53922427]
# 140 116 164
# Ref_lidar [-0.72873956 43.98005    -1.4116448 ]
# Ref_camera [ 0.41552312  1.03881585 43.12037767]
# box_lidar [-0.8549553230713113, 44.31818906302723, -1.4389471277996047]
# box_camera [ 0.29791976  1.06729201 43.46151255]
# 142 118 166
# Ref_lidar [-0.86022925 43.996277   -1.4930618 ]
# Ref_camera [ 0.2840873   1.11967357 43.13956766]
# box_lidar [-0.9104936633557351, 44.23065408281019, -1.4562457083831084]
# box_camera [ 0.24005981  1.08385463 43.37534976]
# 144 120 168
# Ref_lidar [-0.91666687 44.070843   -1.5682628 ]
# Ref_camera [ 0.22921103  1.19499176 43.21517346]
# box_lidar [-0.9795118162429488, 44.155240593618636, -1.4265533835523618]
# box_camera [ 0.16927294  1.05342588 43.30189471]
# 146 122 170
# Ref_lidar [-0.97494185 44.034866   -1.7274075 ]
# Ref_camera [ 0.16922996  1.35365659 43.1798884 ]
# box_lidar [-0.9972652001719644, 44.08233620219482, -1.4334741037649077]
# box_camera [ 0.14961379  1.05987325 43.22943729]
# 148 124 172
# Ref_lidar [-0.94233966 43.888832   -1.8514122 ]
# Ref_camera [ 0.19743771  1.47704367 43.03242307]
# box_lidar [-1.0342761833507736, 43.880572485154985, -1.4871241886944837]
# box_camera [ 0.10715104  1.11227172 43.02841973]
# 150 126 174
# Ref_lidar [-1.0480907 43.835007  -1.7906516]
# Ref_camera [ 0.09064258  1.41548217 42.98165607]
# box_lidar [-1.092663585115299, 43.74200981856394, -1.4091955685561788]
# box_camera [ 0.04560777  1.03332528 42.89181279]
# 152 128 176
# Ref_lidar [-1.0462871 43.784546  -1.9004085]
# Ref_camera [ 0.09059474  1.52497768 42.9305986 ]
# box_lidar [-1.1195286462822964, 43.60273643159899, -1.4188353081578264]
# box_camera [1.51175963e-02 1.04209533e+00 4.27532301e+01]
# 154 130 178
# Ref_lidar [-1.1407528 43.623905  -1.8747418]
# Ref_camera [-7.84554873e-03  1.49799833e+00  4.27725808e+01]
# box_lidar [-1.2713087737848665, 43.401881934687665, -1.38815470070714]
# box_camera [-0.14162756  1.00960878 42.55651552]
# 156 132 180
# Ref_lidar [-1.725362  42.462185  -1.7231663]
# Ref_camera [-0.62140287  1.33741126 41.62711315]
# box_lidar [-1.327157195832888, 43.2497338504625, -1.4336894104496927]
# box_camera [-0.20160302  1.05406289 42.40562393]
# 158 134 182
# Ref_lidar [-1.6646725 42.42718   -1.5843561]
# Ref_camera [-0.56093791  1.19871594 41.59127527]
# box_lidar [-1.4256895867730746, 43.025732605184025, -1.5298669668992768]
# box_camera [-0.30635231  1.14856898 42.18374221]
# 160 136 184
# Ref_lidar [-1.6805806 42.350708  -1.5016017]
# Ref_camera [-0.57839362  1.11548066 41.51566643]
# box_lidar [-1.474280253804284, 42.90562801688114, -1.422179614949629]
# box_camera [-0.35747739  1.04001031 42.06548837]
# 162 138 186
# Ref_lidar [-1.4058934 42.545982  -1.3490038]
# Ref_camera [-0.29800625  0.96526502 41.70458287]
# box_lidar [-1.4715366441672226, 42.754366022744854, -1.3782965200654171]
# box_camera [-0.35840877  0.9953402  41.91443488]
# 164 140 188
# Ref_lidar [-1.471731  42.41455   -1.3764458]
# Ref_camera [-0.36734303  0.99168779 41.57475164]
# box_lidar [-1.54626923604479, 42.65291317062243, -1.386316889899882]
# box_camera [-0.43576809  1.00245722 41.81490171]
# 166 142 190
# Ref_lidar [-1.5092707 42.285374  -1.2671156]
# Ref_camera [-0.40764631  0.88149231 41.44715211]
# box_lidar [-1.5160730017000785, 42.499895380828946, -1.2312346607567743]
# box_camera [-0.40874261  0.84671584 41.66196055]
# 168 144 192
# Ref_lidar [-1.5180671 42.166603  -1.263994 ]
# Ref_camera [-0.41948207  0.87769836 41.32866541]
# box_lidar [-1.6596295560580887, 42.34525835230415, -1.1394103922338932]
# box_camera [-0.55576975  0.75337236 41.51155174]
# 170 146 194
# Ref_lidar [-1.6060693 41.95443   -1.3200034]
# Ref_camera [-0.51319838  0.93215154 41.11854372]
# box_lidar [-1.6687876272912754, 42.21288423873347, -1.106618662358331]
# box_camera [-0.56816813  0.71983521 41.37962899]
# 172 148 196
# Ref_lidar [-1.693784  41.78725   -1.1989737]
# Ref_camera [-0.60457899  0.80981001 40.95430898]
# box_lidar [-1.760259012759026, 42.097063267474994, -1.0049986417955843]
# box_camera [-0.66207939  0.61715668 41.26673108]
# 174 150 198
# Ref_lidar [-1.7218838 41.594513  -1.2217913]
# Ref_camera [-0.63774625  0.83146823 40.76224422]
# box_lidar [-1.8225245213986083, 41.938276227581895, -0.9326171132043829]
# box_camera [-0.72804802  0.54363105 41.10997802]
# 176 152 200
# Ref_lidar [-1.767468  41.490578  -1.2973206]
# Ref_camera [-0.68637042  0.90622188 40.65912915]
# Generated sequence gif at /staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/viz/sequence_tracks_001255_new.gif
