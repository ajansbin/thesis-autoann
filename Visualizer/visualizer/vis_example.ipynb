# %% [markdown]
# ### Mini - Train

# %%
import importlib
import visualizer
importlib.reload(visualizer)
import visualizer

conf_name = 'w9-rndslides-lr1-3-w0-earlyfuse-fulltransformer_conf.json'
conf_path = f'/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/pc-track/{conf_name}'
version = 'mini'
split = "train"
result_path = f"/staging/agp/masterthesis/2023autoann/storage/tracking/SimpleTrack_zod_{version}_{split}/results/Vehicle/results.json"
data_path = "/datasets/zod/zodv2"
model_name= 'w9-rndslides-lr1-3-w0-earlyfuse-fulltransformer_model.pth'
model_path = f'/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/pc-track/{model_name}'
remove_non_foi_tracks = True
remove_non_gt_tracks = True

viz_mini = visualizer.VisualizeResults(conf_path, version, split, result_path, data_path, remove_non_foi_tracks, remove_non_gt_tracks)
viz_mini.load_model(model_path)
# Out:
# Initializing ZodData class...
# Loading prediction and ground-truths ...
# 100%|██████████| 181/181 [00:00<00:00, 398095.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 16.65it/s]
# Loading sequences...
# 100%|██████████| 1/1 [00:00<00:00, 31.24it/s]
# Finished loading 1 data samples!
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[28], line 18
#      15 remove_non_gt_tracks = True
#      17 viz_mini = visualizer.VisualizeResults(conf_path, version, split, result_path, data_path, remove_non_foi_tracks, remove_non_gt_tracks)
# ---> 18 viz_mini.load_model(model_path)
#
# File ~/workspace/thesis-autoann/Visualizer/visualizer/visualizer.py:90, in VisualizeResults.load_model(self, model_path, new_conf_path)
#      88 if new_conf_path:
#      89     self.conf = load_config(new_conf_path)
# ---> 90 self.trained_model = self._get_trained_model(model_path, self.conf)
#      91 print(f"Succefully loaded model {os.path.basename(model_path)}")
#
# File ~/workspace/thesis-autoann/Visualizer/visualizer/visualizer.py:532, in VisualizeResults._get_trained_model(self, model_path, conf)
#     519 model_cls = self._get_model_cls(self.use_pc, self.use_track)
#     521 model = model_cls(
#     522     track_encoder=track_encoder,
#     523     pc_encoder=pc_encoder,
#    (...)
#     529     dec_out=dec_out_size,
#     530 )
# --> 532 checkpoint = torch.load(model_path)
#     533 model.load_state_dict(checkpoint)
#     534 model.eval()
#
# File ~/miniconda3/envs/spot_env/lib/python3.8/site-packages/torch/serialization.py:607, in load(f, map_location, pickle_module, **pickle_load_args)
#     605             opened_file.seek(orig_position)
#     606             return torch.jit.load(opened_file)
# --> 607         return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     608 return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#
# File ~/miniconda3/envs/spot_env/lib/python3.8/site-packages/torch/serialization.py:882, in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
#     880 unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#     881 unpickler.persistent_load = persistent_load
# --> 882 result = unpickler.load()
#     884 torch._utils._validate_loaded_sparse_tensors()
#     886 return result
#
# File ~/miniconda3/envs/spot_env/lib/python3.8/site-packages/torch/serialization.py:857, in _load.<locals>.persistent_load(saved_id)
#     855 data_type, key, location, size = data
#     856 if key not in loaded_storages:
# --> 857     load_tensor(data_type, size, key, _maybe_decode_ascii(location))
#     858 storage = loaded_storages[key]
#     859 return storage
#
# File ~/miniconda3/envs/spot_env/lib/python3.8/site-packages/torch/serialization.py:846, in _load.<locals>.load_tensor(data_type, size, key, location)
#     843 dtype = data_type(0).dtype
#     845 storage = zip_file.get_storage_from_record(name, size, dtype).storage()
# --> 846 loaded_storages[key] = restore_location(storage, location)
#
# File ~/miniconda3/envs/spot_env/lib/python3.8/site-packages/torch/serialization.py:175, in default_restore_location(storage, location)
#     173 def default_restore_location(storage, location):
#     174     for _, _, fn in _package_registry:
# --> 175         result = fn(storage, location)
#     176         if result is not None:
#     177             return result
#
# File ~/miniconda3/envs/spot_env/lib/python3.8/site-packages/torch/serialization.py:157, in _cuda_deserialize(obj, location)
#     155         return storage_type(obj.size())
#     156 else:
# --> 157     return obj.cuda(device)
#
# File ~/miniconda3/envs/spot_env/lib/python3.8/site-packages/torch/_utils.py:79, in _cuda(self, device, non_blocking, **kwargs)
#      77 else:
#      78     new_type = getattr(torch.cuda, self.__class__.__name__)
# ---> 79     return new_type(self.size()).copy_(self, non_blocking)
#
# RuntimeError: CUDA error: unspecified launch failure
# CUDA kernel errors might be asynchronously reported at some other API call,so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.

# %%
track_index = 0
frame_track_index = 20
viz_mini.plot_track_index(track_index, frame_track_index, show_lidar=False, show_det=True, show_ref=True, show_gt=True, score_thresh=0.0)
# Out:
# Showing track {'sequence_id': '000000', 'tracking_id': 'Vehicle_0_10', 'starting_frame_index': 70, 'track_length': 32, 'foi_index': 88, 'assoc_metric': 'giou', 'assoc_thresh': 0.0, 'has_gt': True, 'gt_dist': tensor(0.7901, dtype=torch.float64)}

# %% [markdown]
# ### Full - Train

# %%
import importlib
import visualizer
importlib.reload(visualizer)
import visualizer

version = 'full'
split = "train"
result_path = f"/staging/agp/masterthesis/2023autoann/storage/tracking/SimpleTrack_zod_{version}_{split}/results/Vehicle/results.json"
remove_non_foi_tracks = False
remove_non_gt_tracks = False

viz_full = visualizer.VisualizeResults(conf_path, version, split, result_path, data_path, remove_non_foi_tracks, remove_non_gt_tracks)
viz_full.load_model(model_path)
# Out:
# Initializing ZodData class...
# Loading train sequences:   0%|          | 0/1165 [00:00<?, ?it/s]
# Loading val sequences:   0%|          | 0/294 [00:00<?, ?it/s]
# Loading prediction and ground-truths ...
# 100%|██████████| 211111/211111 [00:00<00:00, 1364586.36it/s]
# 100%|██████████| 1165/1165 [02:45<00:00,  7.03it/s]
# Loading sequences...
# 100%|██████████| 1165/1165 [04:37<00:00,  4.20it/s]
# Finished loading 71598 data samples!
# Succefully loaded model w9-rndslides-lr3-3-wd1-3-scheduler_model.pth

# %%
### Load new model ###
model_path = '/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/pc-track/w25-no-sw-oldanno_model.pth'
viz_full.load_model(model_path)
# Out:
# Succefully loaded model w25-no-sw-oldanno_model.pth

# %%
track_index = 51515
frame_track_index = 14
viz_full.plot_track_index(track_index, frame_track_index, show_lidar=False, show_det=True, show_ref=True, show_gt=True, score_thresh=0.0)

#interesting: 1199, 7001 (28)
# Out:
# Showing track {'sequence_id': '000070', 'tracking_id': 'Vehicle_54_5', 'starting_frame_index': 9, 'track_length': 15, 'foi_index': None, 'assoc_metric': 'giou', 'assoc_thresh': 0.0, 'has_gt': False, 'gt_dist': None}
# Track does not have gt, skipping gt-box

# %%
viz_full.track_data.slides
# Out:
# 1

# %%
seq_id = '000070'
out_dir = '/staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/viz'
gif_name = f'sequence_tracks_{seq_id}_score05.gif'
step = 2
duration = 400
show_lidar = False
show_det = True
show_ref = True
show_gt = False
score_thresh=0.5

viz_full.generate_sequence_gif(seq_id, out_dir, gif_name, step, duration, show_lidar, show_det, show_ref, show_gt, score_thresh)
# Out:
# Found 34 number of tracks in sequence
# Generated sequence gif at /staging/agp/masterthesis/2023autoann/storage/smoothing/autoannsmoothing/viz/sequence_tracks_000070_score05.gif
